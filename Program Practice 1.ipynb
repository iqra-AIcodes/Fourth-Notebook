# %%
marks = int(input("Enter your marks: "))

if marks >= 80:
    print("Grade: A")
elif marks >= 60:
    print("Grade: B")
elif marks >= 40:
    print("Grade: C")
else:
    print("Grade: Fail")
# Out:
# Enter your marks:  89
# Grade: A

# %%
name = input("Enter your name: ")
food = input("Enter your favourite food: ")

print("Hello", name + "!", "I hope you enjoy eating", food, "today!")
# Out:
# Enter your name:  Iqra
# Enter your favourite food:  Kimchi
# Hello Iqra! I hope you enjoy eating Kimchi today!

# %%
num = int(input("Enter a number for its table: "))

for i in range(1, 11):
    print(num, "x", i, "=", num * i)
# Out:
# Enter a number for its table:  2
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20

# %%
age = int(input("Enter your age: "))

if age < 13:
    print("You are a Child")
elif age < 20:
    print("You are a Teenager")
elif age < 60:
    print("You are an Adult")
else:
    print("You are a Senior")
# Out:
# Enter your age:  18
# You are a Teenager

# %%
password = input("Enter password: ")

if password == "abc123":
    print("Access Granted")
else:
    print("Wrong Password")
# Out:
# Enter password:  iqra
# Wrong Password

# %%
password = input("Enter password: ")

if password == "abc123":
    print("Access Granted")
else:
    print("Wrong Password")
# Out:
# Enter password:  abc123
# Access Granted

# %%
num = int(input("Enter a number: "))

if num > 0:
    print("The number is Positive")
elif num < 0:
    print("The number is Negative")
else:
    print("The number is Zero")
# Out:
# Enter a number:  6
# The number is Positive

# %%
total = int(input("Enter total classes: "))
attended = int(input("Enter classes attended: "))

percentage = (attended / total) * 100

print("Attendance:", percentage, "%")

if percentage >= 75:
    print("You are allowed to sit in exam")
else:
    print("You are NOT allowed to sit in exam")
# Out:
# Enter total classes:  6
# Enter classes attended:  5
# Attendance: 83.33333333333334 %
# You are allowed to sit in exam
