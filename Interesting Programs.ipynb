# %%
temp = int(input("Enter temperature: "))

if temp > 30:
    print("It's too hot 😥")
elif temp > 20:
    print("Nice warm weather 🙂")
elif temp > 10:
    print("It's a bit cold ❄️")
else:
    print("Freezing cold! 🥶")
# Out:
# Enter temperature:  0
# Freezing cold! 🥶

# %%
print("Welcome to Candy Machine")
print("1. Chocolate")
print("2. Jelly")
print("3. Chips")

choice = input("Enter your choice (1/2/3): ")

if choice == "1":
    print("Here is your Chocolate 🍫")
elif choice == "2":
    print("Here is your Jelly 🍬")
elif choice == "3":
    print("Here are your Chips 🍟")
else:
    print("Invalid choice!")
# Out:
# Welcome to Candy Machine
# 1. Chocolate
# 2. Jelly
# 3. Chips
# Enter your choice (1/2/3):  3
# Here are your Chips 🍟

# %%
sleep = int(input("How many hours did you sleep? "))

if sleep >= 8:
    print("Perfect, you are well-rested 😍")
elif sleep >= 6:
    print("Not bad, but sleep more 😴")
else:
    print("Go sleep now!! 😡😂")
# Out:
# How many hours did you sleep?  7
# Not bad, but sleep more 😴

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))

print(f"Happy Birthday {name}!")
print(f"Next year you will be {age + 1} years old 🎂")
# Out:
# Enter your name:  Iqra
# Enter your age:  18
# Happy Birthday Iqra!
# Next year you will be 19 years old 🎂

# %%
snake = input("Draw a snake using ~ : ")

length = len(snake)

print("Snake length:", length)

if length < 5:
    print("Tiny baby snake 🐍")
elif length < 10:
    print("Medium snake 🐍🐍")
else:
    print("Giant snake!!! 🐍🐍🐍")
# Out:
# Draw a snake using ~ :  15
# Snake length: 2
# Tiny baby snake 🐍

# %%
num = int(input("Press 1 to roll dice: "))

if num == 1:
    print("You rolled a 6 🎲 (lucky!)")
else:
    print("Please press 1 only!")
# Out:
# Press 1 to roll dice:  1
# You rolled a 6 🎲 (lucky!)
